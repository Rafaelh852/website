# %%
import numpy as np
import scipy.stats as st
import statsmodels as sm

import os
import pandas as pd
import requests

import matplotlib.pyplot as plt

# %%
baseUrl = "https://api.ers.usda.gov/data/"

#categories for arms/ 
arms = "arms/variable"
# start with & for search options use url formatting , for multiple and + for spaceing
searchOptions = ""

url = baseUrl + arms + "?api_key=" + key + searchOptions
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
r.json()
# Out:
# {'status': 'ok',
#  'info': {'timing': {'executing': 133, 'unit': 'ms'},
#   'result_coverage': 'total',
#   'total': {'record_count': 151}},
#  'data': [{'id': 'kount',
#    'name': 'Farms',
#    'description': 'Estimated number of farms.',
#    'sequence': 10,
#    'is_invalid': False,
#    'group': None,
#    'level': 1,
#    'report': 'Farm Business Balance Sheet',
#    'unit': 'Number'},
#   {'id': 'kount',
#    'name': 'Farms',
#    'description': 'Estimated number of farms.',
#    'sequence': 10,
#    'is_invalid': False,
#    'group': None,
#    'level': 1,
#    'report': 'Farm Business Financial Ratios',
#    'unit': 'Number'},
#   {'id': 'kount',
#    'name': 'Farms',
#    'description': 'Estimated number of farms.',
#    'sequence': 10,
#    'is_invalid': False,
#    'group': None,
#    'level': 1,
#    'report': 'Structural Characteristics',
#    'unit': 'Number'},
#   {'id': 'kntdp',
#    'name': 'Farms',
# ...
